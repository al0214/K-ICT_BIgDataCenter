# %%
print("HelloWorld!!")
# Out:
# HelloWorld!!

# %%
myString = "Hello"

# %%
print(myString)
# Out:
# Hello

# %%
# 변수 할당
a = 300 
# 변수 출력
print(a)
# Out:
# 300

# %%
x = 500
print(x)
# Out:
# 500

# %%
a == x # 두개 값이 같나요?
a is x # 주소가 같나요?
# Out:
# False

# %%
x = 30
print(type(x))
# Out:
# <class 'int'>

# %%
x = 3.141592
print(type(x))
# Out:
# <class 'float'>

# %%
print("He said \"I don\'t Want to do\"")
# Out:
# He said "I don't Want to do"

# %%
print("Life is too short\n learn python")
# Out:
# Life is too short
#  learn python

# %%
print("Life is too short\t learn python")
# Out:
# Life is too short	 learn python

# %%
X = 3
y = 3
hex(id(x)) == hex(id(y))
# Out:
# False

# %%
X = 3000
y = 3000
hex(id(x)) == hex(id(y))
# Out:
# False

# %%
x = '김재우'
print(f'My name is {x}')
# Out:
# My name is 김재우

# %%
print(3**4)
print(4**5)
# Out:
# 81
# 1024

# %%
tep = '20210726SUNNY'
tep.replace("20210726", "20220611")
tep.replace("SUNNY", "HOT")
# Out:
# '20210726HOT'

# %%
a = '비옴'
b = 18.97243
c = 20

print(f"'오늘 날씨는 {a} 이며 섭씨 {b:.0f}도가 되겠습니다. 강수량은 {c:03d}mm 입니다'")
# Out:
# '오늘 날씨는 비옴 이며 섭씨 19도가 되겠습니다. 강수량은 020mm 입니다'

# %%
My_list = ['a','b','c','d','e','f','g']
print(My_list[1:4])
# Out:
# ['b', 'c', 'd']

# %%
year = {
    2019:'돼지',
    2020:"쥐0",
    2021:"소",
    2022:"호랑이"
}

# %%
x = 2022
print(f"올해 {x}년도는 {year[x]}해 입니다")
# Out:
# 올해 2022년도는 호랑이해 입니다

# %%
def cal2(x):
  return x+1
print(cal2(2))
# Out:
# 3

# %%
def cal6(x,y,z):
  return x*y*z

# %%
import numpy as np 
def sphere_volume(r):
  volume = (4/3) * (np.pi) * (r**3)
  return volume 
  
import math 
def sphere_volume(r):
  volume = (4/3) * (math.pi) * (r**3)
  return volume

# %%
# !pip install gTTS # 남이 만들어놓은 코드 다운로드
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import IPython
from gtts import gTTS

# %%
def text2speech(text,name,lang='ko'):
    tts_ko = gTTS(text=text, lang=lang)
    tts_ko.save(name)
    
    return None

# %%
text = """Inspired by progress in large-scale language modeling,
 we apply a similar approach towards building a single generalist agent 
 beyond the realm of text.
"""
name = '1.mp3'
text2speech(text, name, lang='en-uk')
IPython.display.Audio(name)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text= """
이번역은 지상 서울역,  지상 서울력입니다. 내리실 문은 오른쪽입니다.
"""

name = '1.mp3'
text2speech(text, name, lang='ko')
IPython.display.Audio(name)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os
os.getcwd()
os.listdir()
os.path.exists()
os.path.split()
os.path.basename()
# Out:
# '/content'

# %%
# 정형 데이터란 정형화된 형태를 가지고 고정된 필드에 저장되며 값과 형식에서 일관성을 가지는 데이터 열, 행 구조를 가짐 Ex) 관계형데이터페이스RDB, 스프레드시트
# 비정형 데이터 구조 형태를 가지지 않고 고정된 필드에 저장되지 않은 데이터 Ex) 이미지, 비디오, 오디오
# 반정형 데이터 형태 구조를 가지고 메타 데이터를 포함하며 값과 형식에서 일관성을 가지지 않은 데이터 구조가 얼추 저장되어있어서 Ex) XML, HTML, JSON
